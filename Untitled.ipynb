# %%
# !pip3 install git+https://github.com/abey79/vsketch#egg=vsketch
# !pip3 install git+https://github.com/marceloprates/prettymaps.git

# !mkdir ../prints
# !mkdir ../assets
# !mkdir ../assets/Permanent_Marker/
# !wget -o ../assets/Permanent_Marker/PermanentMarker-Regular.ttf https://github.com/marceloprates/prettymaps/blob/master/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Out:
# Requirement already satisfied: vsketch from git+https://github.com/abey79/vsketch#egg=vsketch in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.0.0a0)
# Requirement already satisfied: numpy<2.0.0,>=1.20.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (1.21.2)
# Requirement already satisfied: watchgod<0.8,>=0.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (0.7)
# Requirement already satisfied: vpype[all]==1.7.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (1.7.0)
# Requirement already satisfied: jupyterlab-code-formatter<2.0.0,>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (1.4.10)
# Requirement already satisfied: PySide2<6.0.0,>=5.15.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (5.15.2)
# Requirement already satisfied: pnoise<0.2.0,>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (0.1.0)
# Requirement already satisfied: Shapely[vectorized]<2.0.0,>=1.7.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (1.7.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (3.4.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (0.4.4)
# Requirement already satisfied: cookiecutter<2.0.0,>=1.7.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (1.7.3)
# Requirement already satisfied: bezier>=2021.2.12 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (2021.2.12)
# Requirement already satisfied: qasync<0.16.0,>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (0.15.0)
# Requirement already satisfied: multiprocess<0.71.0,>=0.70.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vsketch) (0.70.12.2)
# Requirement already satisfied: svgelements==1.5.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (1.5.4)
# Requirement already satisfied: setuptools<52.0.0,>=51.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (51.3.3)
# Requirement already satisfied: svgwrite<1.5,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (1.4.1)
# Requirement already satisfied: cachetools<5.0.0,>=4.2.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (4.2.2)
# Requirement already satisfied: attrs<21.3.0,>=21.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (21.2.0)
# Requirement already satisfied: scipy<2.0,>=1.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (1.7.1)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (0.10.2)
# Requirement already satisfied: click<8.1.0,>=8.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (8.0.1)
# Requirement already satisfied: click-plugins<1.2.0,>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (1.1.1)
# Requirement already satisfied: moderngl<6.0.0,>=5.6.2; extra == "all" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (5.6.4)
# Requirement already satisfied: Pillow<9.0.0,>=8.1.0; extra == "all" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (8.3.1)
# Requirement already satisfied: glcontext>=2.3.2; extra == "all" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from vpype[all]==1.7.0->vsketch) (2.3.4)
# Requirement already satisfied: jupyterlab~=3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (3.1.9)
# Requirement already satisfied: shiboken2==5.15.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from PySide2<6.0.0,>=5.15.2->vsketch) (5.15.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (2.4.7)
# Requirement already satisfied: poyo>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (0.5.0)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (2.25.0)
# Requirement already satisfied: binaryornot>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (0.4.4)
# Requirement already satisfied: six>=1.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (1.15.0)
# Requirement already satisfied: python-slugify>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (5.0.2)
# Requirement already satisfied: jinja2-time>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (0.2.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (3.0.1)
# Requirement already satisfied: dill>=0.3.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from multiprocess<0.71.0,>=0.70.11->vsketch) (0.3.4)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (21.0)
# Requirement already satisfied: jupyterlab-server~=2.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.7.2)
# Requirement already satisfied: jupyter-server~=1.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.10.2)
# Requirement already satisfied: nbclassic~=0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.3.1)
# Requirement already satisfied: ipython in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (7.26.0)
# Requirement already satisfied: tornado>=6.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (6.1)
# Requirement already satisfied: jupyter-core in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (1.26.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-slugify>=4.0.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (1.3)
# Requirement already satisfied: arrow in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2-time>=0.2.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (1.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter<2.0.0,>=1.7.2->vsketch) (2.0.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (3.2.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.3)
# Requirement already satisfied: json5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.9.6)
# Requirement already satisfied: babel in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.9.1)
# Requirement already satisfied: argon2-cffi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (20.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.0.5)
# Requirement already satisfied: Send2Trash in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (7.0.1)
# Requirement already satisfied: prometheus-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.11.0)
# Requirement already satisfied: websocket-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.2.1)
# Requirement already satisfied: nbconvert in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (6.1.0)
# Requirement already satisfied: requests-unixsocket in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.2.0)
# Requirement already satisfied: nbformat in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.1.3)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (22.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.11.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (3.3.0)
# Requirement already satisfied: notebook<7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbclassic~=0.2->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (6.4.3)
# Requirement already satisfied: pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.10.0)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.1.2)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.18.0)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.2.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.0.9)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (3.0.20)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.8.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.18.0)
# Requirement already satisfied: pytz>=2015.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from babel->jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2021.1)
# Requirement already satisfied: cffi>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.14.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.5.1)
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.1.0)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.5.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.4.3)
# Requirement already satisfied: testpath in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.1.2)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.7.0)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.2.0)
# Requirement already satisfied: ipykernel in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook<7->nbclassic~=0.2->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (6.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.8.2)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.2.5)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.20)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.4.1)
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Collecting git+https://github.com/marceloprates/prettymaps.git
#   Cloning https://github.com/marceloprates/prettymaps.git to /private/var/folders/60/zff7_6t92yl04sycsl0hm0740000gn/T/pip-req-build-rw2rapq9
# Requirement already satisfied (use --upgrade to upgrade): prettymaps==1.0.0 from git+https://github.com/marceloprates/prettymaps.git in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages
# Requirement already satisfied: osmnx==1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prettymaps==1.0.0) (1.0.1)
# Requirement already satisfied: tabulate==0.8.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prettymaps==1.0.0) (0.8.9)
# Requirement already satisfied: jupyter==1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prettymaps==1.0.0) (1.0.0)
# Requirement already satisfied: Rtree>=0.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (0.9.7)
# Requirement already satisfied: descartes>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (1.1.0)
# Requirement already satisfied: numpy>=1.19 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (1.21.2)
# Requirement already satisfied: Shapely>=1.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (1.7.1)
# Requirement already satisfied: geopandas>=0.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (0.9.0)
# Requirement already satisfied: pandas>=1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (1.3.2)
# Requirement already satisfied: networkx>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (2.6.2)
# Requirement already satisfied: pyproj>=2.6 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (3.1.0)
# Requirement already satisfied: requests>=2.25 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (2.25.0)
# Requirement already satisfied: matplotlib>=3.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from osmnx==1.0.1->prettymaps==1.0.0) (3.4.3)
# Requirement already satisfied: ipykernel in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter==1.0.0->prettymaps==1.0.0) (6.2.0)
# Requirement already satisfied: qtconsole in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter==1.0.0->prettymaps==1.0.0) (5.1.1)
# Requirement already satisfied: nbconvert in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter==1.0.0->prettymaps==1.0.0) (6.1.0)
# Requirement already satisfied: ipywidgets in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter==1.0.0->prettymaps==1.0.0) (7.6.3)
# Requirement already satisfied: jupyter-console in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter==1.0.0->prettymaps==1.0.0) (6.4.0)
# Requirement already satisfied: notebook in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter==1.0.0->prettymaps==1.0.0) (6.4.3)
# Requirement already satisfied: fiona>=1.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (1.8.20)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.1->osmnx==1.0.1->prettymaps==1.0.0) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.1->osmnx==1.0.1->prettymaps==1.0.0) (2.8.2)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pyproj>=2.6->osmnx==1.0.1->prettymaps==1.0.0) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==1.0.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==1.0.0) (1.26.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==1.0.0) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==1.0.0) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==1.0.0) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==1.0.0) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==1.0.0) (2.4.7)
# Requirement already satisfied: appnope; platform_system == "Darwin" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (0.1.2)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (7.26.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (7.0.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (1.4.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (5.0.5)
# Requirement already satisfied: pyzmq>=17.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0->prettymaps==1.0.0) (22.2.1)
# Requirement already satisfied: ipython-genutils in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0->prettymaps==1.0.0) (0.2.0)
# Requirement already satisfied: jupyter-core in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0->prettymaps==1.0.0) (4.7.1)
# Requirement already satisfied: qtpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0->prettymaps==1.0.0) (1.10.0)
# Requirement already satisfied: pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from qtconsole->jupyter==1.0.0->prettymaps==1.0.0) (2.10.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.5.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.3)
# Requirement already satisfied: defusedxml in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (1.4.3)
# Requirement already satisfied: testpath in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.5.0)
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (3.0.1)
# Requirement already satisfied: jupyterlab-pygments in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.1.2)
# Requirement already satisfied: nbformat>=4.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0->prettymaps==1.0.0) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipywidgets->jupyter==1.0.0->prettymaps==1.0.0) (3.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-console->jupyter==1.0.0->prettymaps==1.0.0) (3.0.20)
# Requirement already satisfied: argon2-cffi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->prettymaps==1.0.0) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->prettymaps==1.0.0) (1.8.0)
# Requirement already satisfied: prometheus-client in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->prettymaps==1.0.0) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from notebook->jupyter==1.0.0->prettymaps==1.0.0) (0.11.1)
# Requirement already satisfied: attrs>=17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (21.2.0)
# Requirement already satisfied: cligj>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (0.7.2)
# Requirement already satisfied: munch in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (2.5.0)
# Requirement already satisfied: six>=1.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (1.15.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (51.3.3)
# Requirement already satisfied: click-plugins>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (1.1.1)
# Requirement already satisfied: click>=4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==1.0.0) (8.0.1)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (0.2.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (5.0.9)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (0.18.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (4.8.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (1.5.1)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (21.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2>=2.4->nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (3.2.0)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter==1.0.0->prettymaps==1.0.0) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter==1.0.0->prettymaps==1.0.0) (1.14.6)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0->prettymaps==1.0.0) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->jupyter==1.0.0->prettymaps==1.0.0) (0.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter==1.0.0->prettymaps==1.0.0) (0.18.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter==1.0.0->prettymaps==1.0.0) (2.20)
# Using legacy 'setup.py install' for prettymaps, since package 'wheel' is not installed.
# WARNING: You are using pip version 20.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# mkdir: ../prints: File exists
# mkdir: ../assets: File exists
# mkdir: ../assets/Permanent_Marker/: File exists

# %%
import vsketch
from prettymaps import *
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (12, 12), constrained_layout = True)

backup = plot(
    'Praça Ferreira do Amaral, Macau', radius = 1100,
    
    ax = ax,
    
    layers = {
            'perimeter': {},
            'streets': {
                'custom_filter': '["highway"~"motorway|trunk|primary|secondary|tertiary|residential|service|unclassified|pedestrian|footway"]',
                'width': {
                    'motorway': 5,
                    'trunk': 5,
                    'primary': 4.5,
                    'secondary': 4,
                    'tertiary': 3.5,
                    'residential': 3,
                    'service': 2,
                    'unclassified': 2,
                    'pedestrian': 2,
                    'footway': 1,
                }
            },
            'building': {'tags': {'building': True, 'landuse': 'construction'}, 'union': False},
            'water': {'tags': {'natural': ['water', 'bay']}},
            'green': {'tags': {'landuse': 'grass', 'natural': ['island', 'wood'], 'leisure': 'park'}},
            'forest': {'tags': {'landuse': 'forest'}},
            'parking': {'tags': {'amenity': 'parking', 'highway': 'pedestrian', 'man_made': 'pier'}}
        },
        drawing_kwargs = {
            'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
            'perimeter': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'lw': 0, 'hatch': 'ooo...',  'zorder': 0},
            'green': {'fc': '#D0F1BF', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
            'forest': {'fc': '#64B96A', 'ec': '#2F3737', 'lw': 1, 'zorder': 1},
            'water': {'fc': '#a1e3ff', 'ec': '#2F3737', 'hatch': 'ooo...', 'hatch_c': '#85c9e6', 'lw': 1, 'zorder': 2},
            'parking': {'fc': '#F2F4CB', 'ec': '#2F3737', 'lw': 1, 'zorder': 3},
            'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 3},
            'building': {'palette': ['#FFC857', '#E9724C', '#C5283D'], 'ec': '#2F3737', 'lw': .5, 'zorder': 4},
        }
)

plt.savefig('../prints/macao.png')
plt.savefig('../prints/macao.svg')
